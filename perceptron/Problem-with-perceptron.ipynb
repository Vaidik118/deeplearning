# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input1']=[1,1,0,0]
or_data['input2']=[1,0,1,0]
or_data['ouput']=[1,1,1,0]

# %%
and_data['input1']=[1,1,0,0]
and_data['input2']=[1,0,1,0]
and_data['ouput']=[1,0,0,0]

# %%
xor_data['input1']=[1,1,0,0]
xor_data['input2']=[1,0,1,0]
xor_data['ouput']=[0,1,1,0]

# %%
and_data
# Out:
#    input1  input2  ouput
# 0       1       1      1
# 1       1       0      0
# 2       0       1      0
# 3       0       0      0

# %%
or_data
# Out:
#    input1  input2  ouput
# 0       1       1      1
# 1       1       0      1
# 2       0       1      1
# 3       0       0      0

# %%
xor_data
# Out:
#    input1  input2  ouput
# 0       1       1      0
# 1       1       0      1
# 2       0       1      1
# 3       0       0      0

# %%
sns.scatterplot(
    x=and_data['input1'],
    y=and_data['input2'],
    hue=and_data['ouput'],
    s=500
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
sns.scatterplot(x=or_data['input1'],y=or_data['input2'],hue=or_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
sns.scatterplot(x=xor_data['input1'],y=xor_data['input2'],hue=xor_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
from sklearn.linear_model import Perceptron
clf1=Perceptron()
clf2=Perceptron()
clf3=Perceptron()

# %%
clf1.fit(and_data.iloc[:,0:2].values,and_data.iloc[:,-1].values)
clf2.fit(or_data.iloc[:,0:2].values,or_data.iloc[:,-1].values)
clf3.fit(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
clf1.coef_
# Out:
# array([[2., 2.]])

# %%
clf1.intercept_
# Out:
# array([-2.])

# %%
x=np.linspace(-1,1,5)
y=-x+1

# %%
plt.plot(x,y)
sns.scatterplot(x=and_data['input1'],y=and_data['input2'],hue=and_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
clf2.coef_
# Out:
# array([[2., 2.]])

# %%
clf2.intercept_
# Out:
# array([-1.])

# %%
x1=np.linspace(-1,1,5)
y1=-x+0.5

# %%
plt.plot(x1,y1)
sns.scatterplot(x=or_data['input1'],y=or_data['input2'],hue=or_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
clf3.coef_
# Out:
# array([[0., 0.]])

# %%
clf3.intercept_
# Out:
# array([0.])

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (0.25.0)
# Requirement already satisfied: scipy>=1.16.3 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from mlxtend) (1.18.1)
# Requirement already satisfied: numpy>=2.3.5 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from mlxtend) (2.5.3)
# Requirement already satisfied: pandas>=2.3.3 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from mlxtend) (3.0.6)
# Requirement already satisfied: scikit-learn>=1.8.0 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from mlxtend) (1.9.1)
# Requirement already satisfied: matplotlib>=3.10.8 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from mlxtend) (3.11.2)
# Requirement already satisfied: joblib>=1.5.2 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from mlxtend) (1.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from joblib>=1.5.2->mlxtend) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (26.3)
# Requirement already satisfied: pillow>=9 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from scikit-learn>=1.8.0->mlxtend) (2.26.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in ./PycharmProjects/deeplearning/.venv/lib/python3.14/site-packages (from scikit-learn>=1.8.0->mlxtend) (3.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt

X = xor_data.iloc[:, 0:2].values
y = xor_data.iloc[:, -1].values

plot_decision_regions(
    X=X,
    y=y,
    clf=clf3,
    legend=2
)

plt.show()
